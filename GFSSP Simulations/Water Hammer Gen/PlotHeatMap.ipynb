# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
open_times = np.array([0.25, 0.5, 0.75, 1])
close_times = np.array([0.5, 1, 1.5, 2, 2.5, 3])

data = np.array([
    [271, 209, 187, 174, 165, 160],
    [271, 209, 187, 174, 165, 160],
    [268, 208, 186, 174, 164, 160],
    [265, 207, 185, 173, 163, 159]
])

plt.rc('font', size = 14)

ax = sns.heatmap(data, annot = True, fmt = '.0f', cmap='viridis', xticklabels = ["0.5", "1.0", "1.5", "2.0", "2.5", "3.0"], yticklabels = ["1.0", "0.75", "0.5", "0.25"])
ax.set_xlabel("Valve Close Time (s)")
ax.set_ylabel("Valve Open Time (s)")
# Out:
# Text(45.722222222222214, 0.5, 'Valve Open Time (s)')
